# %% [markdown]
# ## Bootstrap
#
# **In a nutshell**: Bootstrapping helps estimation of statisc values (e.g. mean, median) of a large population by repeatedly drawing random samples from sample pupolation and calculate the desired statisc value. When a sample is drawn from the sample population, it must be replaced (Sample with Replacement). For example, a set of sample data contains `[2, 5, 7, 8, 9]`, after we draw 8 from the data, sample data must maintain the original shape `[2, 5, 7, 8, 9]`.

# %%
# Libraries for processing arrays faster
import numpy as np
import pandas as pd
# Libraries for drawing graph
import seaborn as sns
import matplotlib.pyplot as plt

# %%
couple_df = pd.read_stata('./couple.dta')

# %%
couple_df.head()
# Out:
#    CaseID  CASEID_NEW      qflag  weight1  weight1_freqwt  weight2  weight1a  \
# 0       2     2014039  Qualified      NaN             NaN   0.8945       NaN
# 1       3     2019003  Qualified   0.9078         71115.0      NaN    0.9026
# 2       5     2145527  Qualified   0.7205         56442.0      NaN    0.7164
# 3       6     2648857  Qualified   1.2597         98682.0   1.3507    1.2524
# 4       7     2623465  Qualified   0.8686         68044.0      NaN    0.8636
#
#    weight1a_freqwt  weight_combo  weight_combo_freqwt  ...  \
# 0              NaN      0.277188              19240.0  ...
# 1          70707.0      1.020621              70841.0  ...
# 2          56121.0      0.810074              56227.0  ...
# 3          98110.0      0.418556              29052.0  ...
# 4          67652.0      0.976522              67781.0  ...
#
#    hcm2017q24_met_through_family hcm2017q24_met_through_friend  \
# 0                             no                            no
# 1                             no                            no
# 2                             no                            no
# 3                             no                            no
# 4                             no                            no
#
#   hcm2017q24_met_through_as_nghbrs hcm2017q24_met_as_through_cowork  \
# 0                               no                               no
# 1                               no                              yes
# 2                               no                               no
# 3                               no                               no
# 4                              yes                               no
#
#   w6_subject_race interracial_5cat partner_mother_yrsed subject_mother_yrsed  \
# 0           White               no                 12.0                 14.0
# 1           White               no                 12.0                 16.0
# 2           White               no                  9.0                  7.5
# 3           White               no                 16.0                 12.0
# 4           White               no                 14.0                 17.0
#
#   partner_yrsed subject_yrsed
# 0          12.0          14.0
# 1          17.0          17.0
# 2          14.0          17.0
# 3          12.0          12.0
# 4          16.0          16.0
#
# [5 rows x 285 columns]

# %%
couple_df.shape
# Out:
# (3510, 285)

# %%
couple_df.describe().T
# Out:
#                                count          mean            std  \
# CaseID                        3510.0  2.121319e+03    1241.582562
# CASEID_NEW                    3510.0  2.181073e+06  640129.459718
# weight1                       2994.0  9.999994e-01       0.285004
# weight1_freqwt                2994.0  7.833742e+04   22326.498047
# weight2                        551.0  1.000003e+00       0.908374
# weight1a                      3110.0  1.000001e+00       0.289889
# weight1a_freqwt               3110.0  7.833766e+04   22709.193359
# weight_combo                  3510.0  9.999996e-01       0.437515
# weight_combo_freqwt           3510.0  6.941018e+04   30367.962891
# duration                      3510.0  2.674499e+02    1406.882283
# Q16                           2836.0  3.495416e+00       5.095177
# w6_q9                         3374.0  4.877712e+01      17.119645
# w6_q16                        3367.0  3.463914e+00       5.109420
# w6_q17                        3385.0  1.014771e+00       0.801753
# w6_q21a_year                  3341.0  1.994229e+03      17.108283
# w6_q21b_year                  3276.0  1.995875e+03      16.741519
# w6_q21b_month_flag            3301.0  3.907907e-02       0.193812
# w6_q21c_year                  2630.0  1.994571e+03      16.034225
# w6_q21c_month_flag              80.0  1.000000e+00       0.000000
# w6_q21d_year                  2169.0  1.992834e+03      16.470289
# w6_q21e_year                   410.0  2.008049e+03       9.757077
# w6_q21f_year                    96.0  2.007000e+03       9.977870
# w6_outness_timing_all          476.0  2.224160e+01       9.433113
# w6_q24_length                 3394.0  1.828544e+02     236.993225
# w6_q26                        1799.0  1.758199e+00       0.436015
# w6_number_people_met          3359.0  4.487943e-01       2.849525
# relate_duration_at_w6_years   2765.0  2.155346e+01      16.650282
# w6_number_people_met_app       323.0  1.752322e+00       5.072208
# weight_combo_v2               3510.0  9.999995e-01       0.412794
# female                        3510.0  5.025641e-01       0.500065
# year_fraction_met             3341.0  1.994715e+03      17.106382
# year_fraction_relstart        3276.0  1.996379e+03      16.735859
# age_when_met                  3341.0  2.665100e+01      11.831783
# time_from_met_to_rel          3263.0  1.597072e+00       4.361398
# year_fraction_first_cohab     2630.0  1.995075e+03      16.026434
# time_from_rel_to_cohab        2578.0  1.900668e+00       2.727196
# hcm2017_q24_length            3394.0  1.829125e+02     237.105133
# hcm2017q24_summary_all_codes  3295.0  1.978756e+00       1.118986
# partner_mother_yrsed          3323.0  1.213873e+01       3.309459
# subject_mother_yrsed          3378.0  1.227975e+01       3.229569
# partner_yrsed                 3383.0  1.403325e+01       2.544955
# subject_yrsed                 3510.0  1.394587e+01       2.546061
#
#                                        min           25%           50%  \
# CaseID                            2.000000  1.040250e+03  2.118500e+03
# CASEID_NEW                    53001.000000  1.825512e+06  2.282692e+06
# weight1                           0.264700  8.080000e-01  9.439000e-01
# weight1_freqwt                20736.000000  6.329700e+04  7.394300e+04
# weight2                           0.190300  5.196500e-01  7.133000e-01
# weight1a                          0.263200  8.050000e-01  9.467500e-01
# weight1a_freqwt               20618.000000  6.306200e+04  7.416600e+04
# weight_combo                      0.058970  8.186115e-01  1.012706e+00
# weight_combo_freqwt            4093.000000  5.681975e+04  7.029200e+04
# duration                          0.000000  8.000000e+00  1.100000e+01
# Q16                               0.000000  0.000000e+00  2.000000e+00
# w6_q9                            -1.000000  3.400000e+01  5.000000e+01
# w6_q16                            0.000000  0.000000e+00  2.000000e+00
# w6_q17                            0.000000  1.000000e+00  1.000000e+00
# w6_q21a_year                   1939.000000  1.981000e+03  1.998000e+03
# w6_q21b_year                   1942.000000  1.983000e+03  2.000000e+03
# w6_q21b_month_flag                0.000000  0.000000e+00  0.000000e+00
# w6_q21c_year                   1944.000000  1.983000e+03  1.997000e+03
# w6_q21c_month_flag                1.000000  1.000000e+00  1.000000e+00
# w6_q21d_year                   1944.000000  1.980000e+03  1.995000e+03
# w6_q21e_year                   1975.000000  2.002000e+03  2.012000e+03
# w6_q21f_year                   1973.000000  2.004000e+03  2.010000e+03
# w6_outness_timing_all             0.000000  1.700000e+01  2.000000e+01
# w6_q24_length                     0.000000  5.400000e+01  1.240000e+02
# w6_q26                           -1.000000  2.000000e+00  2.000000e+00
# w6_number_people_met              0.000000  0.000000e+00  0.000000e+00
# relate_duration_at_w6_years      -0.333333  7.250000e+00  1.808333e+01
# w6_number_people_met_app          0.000000  0.000000e+00  0.000000e+00
# weight_combo_v2                   0.082981  8.096830e-01  9.971581e-01
# female                            0.000000  0.000000e+00  1.000000e+00
# year_fraction_met              1939.208374  1.981708e+03  1.998208e+03
# year_fraction_relstart         1942.375000  1.983792e+03  2.000042e+03
# age_when_met                      0.000000  1.800000e+01  2.300000e+01
# time_from_met_to_rel              0.000000  0.000000e+00  1.667480e-01
# year_fraction_first_cohab      1944.375000  1.983208e+03  1.997417e+03
# time_from_rel_to_cohab            0.000000  3.333740e-01  1.000000e+00
# hcm2017_q24_length                0.000000  5.400000e+01  1.240000e+02
# hcm2017q24_summary_all_codes      0.000000  1.000000e+00  2.000000e+00
# partner_mother_yrsed              0.000000  1.200000e+01  1.200000e+01
# subject_mother_yrsed              0.000000  1.200000e+01  1.200000e+01
# partner_yrsed                     0.000000  1.200000e+01  1.300000e+01
# subject_yrsed                     0.000000  1.200000e+01  1.300000e+01
#
#                                        75%           max
# CaseID                        3.189750e+03  4.311000e+03
# CASEID_NEW                    2.759544e+06  2.972135e+06
# weight1                       1.142650e+00  2.671000e+00
# weight1_freqwt                8.951225e+04  2.092390e+05
# weight2                       1.134700e+00  7.797400e+00
# weight1a                      1.145200e+00  2.751100e+00
# weight1a_freqwt               8.971225e+04  2.155140e+05
# weight_combo                  1.245077e+00  3.110826e+00
# weight_combo_freqwt           8.642100e+04  2.159230e+05
# duration                      1.900000e+01  2.213500e+04
# Q16                           5.000000e+00  5.000000e+01
# w6_q9                         6.200000e+01  9.500000e+01
# w6_q16                        5.000000e+00  5.000000e+01
# w6_q17                        1.000000e+00  4.000000e+00
# w6_q21a_year                  2.009000e+03  2.017000e+03
# w6_q21b_year                  2.010000e+03  2.017000e+03
# w6_q21b_month_flag            0.000000e+00  1.000000e+00
# w6_q21c_year                  2.009000e+03  2.017000e+03
# w6_q21c_month_flag            1.000000e+00  1.000000e+00
# w6_q21d_year                  2.008000e+03  2.017000e+03
# w6_q21e_year                  2.016000e+03  2.017000e+03
# w6_q21f_year                  2.014000e+03  2.017000e+03
# w6_outness_timing_all         2.600000e+01  7.000000e+01
# w6_q24_length                 2.227500e+02  3.855000e+03
# w6_q26                        2.000000e+00  2.000000e+00
# w6_number_people_met          0.000000e+00  7.500000e+01
# relate_duration_at_w6_years   3.416667e+01  7.516666e+01
# w6_number_people_met_app      1.000000e+00  3.500000e+01
# weight_combo_v2               1.223694e+00  3.400087e+00
# female                        1.000000e+00  1.000000e+00
# year_fraction_met             2.009458e+03  2.017542e+03
# year_fraction_relstart        2.010958e+03  2.017875e+03
# age_when_met                  3.200000e+01  8.400000e+01
# time_from_met_to_rel          1.083252e+00  5.475000e+01
# year_fraction_first_cohab     2.009292e+03  2.017542e+03
# time_from_rel_to_cohab        2.416626e+00  3.675000e+01
# hcm2017_q24_length            2.227500e+02  3.855000e+03
# hcm2017q24_summary_all_codes  3.000000e+00  7.000000e+00
# partner_mother_yrsed          1.300000e+01  2.000000e+01
# subject_mother_yrsed          1.400000e+01  2.000000e+01
# partner_yrsed                 1.600000e+01  2.000000e+01
# subject_yrsed                 1.600000e+01  2.000000e+01

# %%
couple_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3510 entries, 0 to 3509
# Data columns (total 285 columns):
#  #    Column                            Dtype
# ---   ------                            -----
#  0    CaseID                            int16
#  1    CASEID_NEW                        int32
#  2    qflag                             category
#  3    weight1                           float64
#  4    weight1_freqwt                    float32
#  5    weight2                           float64
#  6    weight1a                          float64
#  7    weight1a_freqwt                   float32
#  8    weight_combo                      float32
#  9    weight_combo_freqwt               float32
#  10   duration                          int16
#  11   speed_flag                        category
#  12   consent                           category
#  13   xlgb                              category
#  14   S1                                category
#  15   S2                                category
#  16   S3                                category
#  17   DOV_Branch                        category
#  18   Q3_Refused                        category
#  19   Q4                                category
#  20   Q5                                category
#  21   Q6A                               category
#  22   Q6B                               category
#  23   Q9                                category
#  24   Q10                               category
#  25   Q11                               category
#  26   Q12                               category
#  27   Q14                               category
#  28   Q15A7                             category
#  29   Q16                               float64
#  30   Q16_Refused                       category
#  31   Q17A                              category
#  32   Q17B                              category
#  33   Q17C                              category
#  34   Q17D                              category
#  35   Q19                               category
#  36   Q20                               category
#  37   Q21A_Year                         category
#  38   Q21A_Month                        category
#  39   Q21B_Year                         category
#  40   Q21B_Month                        category
#  41   Q21C_Year                         category
#  42   Q21C_Month                        category
#  43   Q21D_Year                         category
#  44   Q21D_Month                        category
#  45   w6_identity                       category
#  46   w6_outness                        category
#  47   w6_outness_timing                 category
#  48   Q23                               category
#  49   Q24_Refused                       category
#  50   Q25                               category
#  51   Q26                               category
#  52   Q27                               category
#  53   Q28                               category
#  54   w6_friend_connect_1               category
#  55   w6_friend_connect_2               category
#  56   w6_friend_connect_3               category
#  57   w6_friend_connect_4               category
#  58   w6_friend_connect_Refused         category
#  59   Q32                               category
#  60   Q34                               category
#  61   Q35_Refused                       category
#  62   w6_sex_frequency                  category
#  63   w6_otherdate                      category
#  64   w6_how_many                       category
#  65   w6_how_meet_Refused               category
#  66   w6_otherdate_app                  category
#  67   w6_how_many_app                   category
#  68   Past_Partner_Q1                   category
#  69   w6_relationship_end_nonmar        category
#  70   w6_breakup_nonmar                 category
#  71   w6_relationship_end_mar           category
#  72   w6_who_breakup                    category
#  73   Q5_2                              category
#  74   Q6A_2                             category
#  75   Q9B_2                             category
#  76   Q10_2                             category
#  77   Q11_2                             category
#  78   Q12_2                             category
#  79   Q14_2                             category
#  80   Q15A7_2_1                         category
#  81   Q16_2                             category
#  82   Q16_2_Codes                       category
#  83   Q17B_2                            category
#  84   Q17C_2                            category
#  85   Q17D_2                            category
#  86   Q20_2                             category
#  87   Q21A_2_Year                       category
#  88   Q21A_2_Month                      category
#  89   Q21B_2_Year                       category
#  90   Q21B_2_Month                      category
#  91   Q21C_2_Year                       category
#  92   Q21C_2_Month                      category
#  93   Q21D_2_Year                       category
#  94   Q21D_2_Month                      category
#  95   Q21E_2_Year                       category
#  96   Q21E_2_Month                      category
#  97   Q21F_2_start_range                category
#  98   Q21F_2_Year                       category
#  99   Q21F_2_Month                      category
#  100  w6_identity_2                     category
#  101  w6_outness_2                      category
#  102  w6_outness_timing_2               category
#  103  Q23_2                             category
#  104  Q25_2                             category
#  105  Q26_2                             category
#  106  Q27_2                             category
#  107  Q28_2                             category
#  108  w6_friend_connect_2_1             category
#  109  w6_friend_connect_2_2             category
#  110  w6_friend_connect_2_3             category
#  111  w6_friend_connect_2_4             category
#  112  w6_friend_connect_2_Refused       category
#  113  Q32_2                             category
#  114  w6_otherdate_2                    category
#  115  w6_how_many_2                     category
#  116  w6_otherdate_app_2                category
#  117  w6_how_many_app_2                 category
#  118  partyid7                          category
#  119  PERSNET_hom                       category
#  120  ppc10017                          category
#  121  ppc21310                          category
#  122  ppp20071                          category
#  123  ppp20072                          category
#  124  ppage                             category
#  125  ppagecat                          category
#  126  ppagect4                          category
#  127  ppeduc                            category
#  128  ppeducat                          category
#  129  ppethm                            category
#  130  ppgender                          category
#  131  pphhhead                          category
#  132  pphhsize                          category
#  133  pphouse                           category
#  134  ppincimp                          category
#  135  ppmarit                           category
#  136  ppmsacat                          category
#  137  PPREG4                            category
#  138  ppreg9                            category
#  139  pprent                            category
#  140  PPT01                             category
#  141  PPT25                             category
#  142  PPT612                            category
#  143  PPT1317                           category
#  144  PPT18OV                           category
#  145  ppwork                            category
#  146  Race_1                            category
#  147  Race_2                            category
#  148  Race_3                            category
#  149  Race_4                            category
#  150  Race_5                            category
#  151  Race_6                            category
#  152  race1                             category
#  153  race2                             category
#  154  race3                             category
#  155  race4                             category
#  156  race5                             category
#  157  race6                             category
#  158  race7                             category
#  159  race8                             category
#  160  race9                             category
#  161  race10                            category
#  162  race11                            category
#  163  race12                            category
#  164  race13                            category
#  165  race14                            category
#  166  race15                            category
#  167  w6_took_the_survey                category
#  168  w6_prior_identity_lgb             category
#  169  w6_same_sex_couple                category
#  170  w6_same_sex_couple_gender         category
#  171  w6_q4                             category
#  172  w6_q5                             category
#  173  w6_q6a                            category
#  174  w6_q6b                            category
#  175  w6_q9                             float64
#  176  w6_q10                            category
#  177  w6_q11                            category
#  178  w6_q12                            category
#  179  w6_q14                            category
#  180  w6_q15a1_truncated                category
#  181  w6_q15a4_truncated                category
#  182  w6_q15a7                          category
#  183  w6_q16                            float64
#  184  w6_q17                            float64
#  185  w6_attraction                     category
#  186  w6_q19                            category
#  187  w6_q20                            category
#  188  w6_q21a_year                      float64
#  189  w6_q21a_month                     category
#  190  w6_q21a_month_flag                category
#  191  w6_q21b_year                      float64
#  192  w6_q21b_month                     category
#  193  w6_q21b_month_flag                float64
#  194  w6_q21c_year                      float64
#  195  w6_q21c_month                     category
#  196  w6_q21c_month_flag                float64
#  197  w6_q21d_year                      float64
#  198  w6_q21d_month                     category
#  199  w6_q21e_year                      float64
#  200  w6_q21e_month                     category
#  201  w6_q21f_year                      float64
#  202  w6_q21f_month                     category
#  203  w6_identity_all                   category
#  204  w6_outness_all                    category
#  205  w6_outness_timing_all             float64
#  206  w6_q23                            category
#  207  w6_q24_length                     float32
#  208  w6_q25                            category
#  209  w6_q26                            float64
#  210  w6_q27                            category
#  211  w6_q28                            category
#  212  w6_friend_connect_1_all           category
#  213  w6_friend_connect_2_all           category
#  214  w6_friend_connect_3_all           category
#  215  w6_friend_connect_4_all           category
#  216  w6_q32                            category
#  217  w6_q34                            category
#  218  w6_otherdate_all                  category
#  219  w6_how_many_all                   category
#  220  w6_otherdate_app_all              category
#  221  w6_how_many_app_all               category
#  222  w6_number_people_met              float32
#  223  w6_otherdate_dichotomous          category
#  224  w6_married                        category
#  225  relate_duration_at_w6_years       float32
#  226  w6_number_people_met_app          float32
#  227  weight_combo_v2                   float32
#  228  partnership_status                category
#  229  female                            int8
#  230  year_fraction_met                 float32
#  231  year_fraction_relstart            float32
#  232  age_when_met                      float32
#  233  time_from_met_to_rel              float32
#  234  year_fraction_first_cohab         float32
#  235  time_from_rel_to_cohab            float32
#  236  hcm2017q24_R_cowork               category
#  237  hcm2017q24_R_friend               category
#  238  hcm2017q24_R_family               category
#  239  hcm2017q24_R_sig_other            category
#  240  hcm2017q24_R_neighbor             category
#  241  hcm2017q24_P_cowork               category
#  242  hcm2017q24_P_friend               category
#  243  hcm2017q24_P_family               category
#  244  hcm2017q24_P_sig_other            category
#  245  hcm2017q24_P_neighbor             category
#  246  hcm2017q24_btwn_I_cowork          category
#  247  hcm2017q24_btwn_I_friend          category
#  248  hcm2017q24_btwn_I_family          category
#  249  hcm2017q24_btwn_I_sig_other       category
#  250  hcm2017q24_btwn_I_neighbor        category
#  251  hcm2017q24_school                 category
#  252  hcm2017q24_college                category
#  253  hcm2017q24_mil                    category
#  254  hcm2017q24_church                 category
#  255  hcm2017q24_vol_org                category
#  256  hcm2017q24_customer               category
#  257  hcm2017q24_bar_restaurant         category
#  258  hcm2017q24_party                  category
#  259  hcm2017q24_internet_other         category
#  260  hcm2017q24_internet_dating        category
#  261  hcm2017q24_internet_soc_network   category
#  262  hcm2017q24_internet_game          category
#  263  hcm2017q24_internet_chat          category
#  264  hcm2017q24_internet_org           category
#  265  hcm2017q24_public                 category
#  266  hcm2017q24_blind_date             category
#  267  hcm2017q24_vacation               category
#  268  hcm2017q24_single_serve_nonint    category
#  269  hcm2017q24_business_trip          category
#  270  hcm2017q24_work_neighbors         category
#  271  hcm2017q24_met_online             category
#  272  hcm2017_q24_length                float32
#  273  hcm2017q24_summary_all_codes      float64
#  274  w6_relationship_quality           category
#  275  hcm2017q24_met_through_family     category
#  276  hcm2017q24_met_through_friend     category
#  277  hcm2017q24_met_through_as_nghbrs  category
#  278  hcm2017q24_met_as_through_cowork  category
#  279  w6_subject_race                   category
#  280  interracial_5cat                  category
#  281  partner_mother_yrsed              float32
#  282  subject_mother_yrsed              float32
#  283  partner_yrsed                     float32
#  284  subject_yrsed                     float32
# dtypes: category(243), float32(20), float64(18), int16(2), int32(1), int8(1)
# memory usage: 1.7 MB

# %%
couple_df['w6_sex_frequency'].unique()
# Out:
# [NaN, 'Once a month or less', '2 to 3 times a month', '3 to 6 times a week', 'Once or twice a week', 'Once a day or more', 'Refused']
# Categories (6, object): ['Refused' < 'Once a day or more' < '3 to 6 times a week' < 'Once or twice a week' < '2 to 3 times a month' < 'Once a month or less']

# %% [markdown]
# S1: Are you married?
# S2: Do you have a boyfriend, a girlfriend, a sexual partner or a romantic partner?
# S3: Have you EVER had a boyfriend, a girlfriend, or a sexual or romantic partner?
# Q9: How old is your partner?
# Q32: Did you use an Internet service to meet your partner?

# %%
["S1", "S2", "S3", "Q9", "Q32"]
# couple_df.drop(["qflag", "weight1", "weight1_freqwt"], axis=1, inplace=True)

# %%
couple_df["Q32"].head()
# Out:
# 0                                                  NaN
# 1    No, I did NOT meet [Partner Name] through the ...
# 2    Yes, an Internet dating or matchmaking site (l...
# 3                                                  NaN
# 4    No, I did NOT meet [Partner Name] through the ...
# Name: Q32, dtype: category
# Categories (8, object): ['Refused' < 'No, I did NOT meet [Partner Name] through the... < 'Yes, a social networking site (like Facebook ... < 'Yes, an Internet dating or matchmaking site (... < 'Yes, an Internet classified advertising site ... < 'Yes, an Internet chat room' < 'Yes, a different kind of Internet service' < 'Yes, an app on my phone (like Tinder or Grindr)']

# %%
sns.set(font_scale=1.5)
sns.displot(data=couple_df, x="w6_sex_frequency", hue="Q32", height=8, multiple="stack")
plt.tick_params(axis='x', rotation=90)

# %%
sns.scatterplot(data=df, x="Age 1st time", y="Slut", hue="Subj.Gender")
# Out:
# <AxesSubplot:xlabel='Age 1st time', ylabel='Slut'>

# %%
population_of_interests = df[df["chol"] > 200]

# %%
# This value will be used to examine the value we get by bootstrapping
population_mean = population_of_interests["age"].mean()

# %%
sns.distplot(population_of_interests["age"])

# %% [markdown]
# ## Beginning of Bootstrap

# %%
sample_population = population_of_interests.sample(30, replace=True)

# %%
sample_population.head(5)

# %% [markdown]
# ## Normal/Gaussian Distribution:
# **In a nutshell**: A bell shaped curve that flats out at both end of the peak. Many things that happen in nature follows this curve. For example, blood pressures of people who're still alive. The average blood pressure of healthy people is around 120 mm Hg. Most people that're alive is relatively health and have blood pressure close to that value, few people who are ill have blood pressure a bit far away from the average, and those who're significantly above or below that is either in dying or dead, so they're excluded from the population of interest.
# **y-axis**: Number of occurrence of a specific value.
# **x-axis**: Value of interest, such as blood pressure, age, resting heart rate.
# ![example](./nd_example.png)
# [image from Stack Overflow](https://stackoverflow.com/questions/10138085/python-plot-normal-distribution)
#
# ## Central Limit Therom
# **In a nutshell**: If one draws repeatedly from a sample with replacement, calculate the statistic value of interest (e.g mean, median), and aggregate these values, then the distribution of thses value will be approximately normally distributed.
# There're no set rules on how many time we need to randomly draw from the sample, but a good place to start is 1000, and use intuition and observation to increase that number.

# %%
n_iterations = 3000
n_size = len(t_sample)
sampling_means_distribution = []
# Run the loop 3000 times, draw random samples in each loop and get there mean
for i in range(n_iterations):
    resample = t_sample.sample(n_size, replace=True)
    resample_mean = resample["age"].mean()
    sampling_means_distribution.append(resample_mean)

# %%
np_smd = np.array(sampling_means_distribution)

# %%
sns.distplot(np_smd)

# %% [markdown]
# ## Confidence Interval
# **Bootstrapping** can **NOT** help us find the true value of the population of interests. Since we can't determine that value, we need a reasonable way to estimate that value the boostrapped value.
#
# Confidence Interval is a way we estimate that values of the population, in this case the mean age of the population who's level of cholesteral exceeds 200 mg/dL.
#
# **Confidence Interval** is a range of value (e.g. between 50 - 60) that we're think the statistic value (mean) of the population of interest lie within.
#
# To construct a 95% Confidence Interval, we can sort the data from smallest to largest, and get the value that's on `data_length * 0.025` from the start and `data_length * 0.025` from the end.

# %%
sorted_smd = np.sort(np_smd)

# %%
# Get value from array and convert to integer.
lower_percentile = sorted_smd[int(n_iterations * n_size * 0.0025)]
upper_percentile = sorted_smd[int(n_iterations - lower_percentile)]

# %%
confidence_interval = [lower_percentile, upper_percentile]

# %% [markdown]
# In this case, we could say we're 95% certain that the true mean of the population of interest is between 55 to 60.

# %%
confidence_interval

# %%
(round(population_mean) >=
